# %%
import gmc_project
# Out:
# ---------
# telenvi package 4.0.6
# ---------
# ---------
# GeoMultiCorr 0.0.0
# ---------

# %%
# Création d'un projet blanc
maurienne = gmc_project.create_new('/media/duvanelt/TD002/sandbox_gmc/maurienne')

# %%
maurienne.get_pairs('pierre-brune')
# Out:
# [---------
#  type   : GMC_Pair
#  pzone  : pierre-brune
#  left   : 2001-08-01-AERIAL
#  right  : 2006-09-13-AERIAL
#  status : empty
#  ---------,
#  ---------
#  type   : GMC_Pair
#  pzone  : pierre-brune
#  left   : 2001-08-01-AERIAL
#  right  : 2009-08-27-AERIAL
#  status : empty
#  ---------,
#  ---------
#  type   : GMC_Pair
#  pzone  : pierre-brune
#  left   : 2001-08-01-AERIAL
#  right  : 2013-07-31-AERIAL
#  status : empty
#  ---------,
#  ---------
#  type   : GMC_Pair
#  pzone  : pierre-brune
#  left   : 2001-08-01-AERIAL
#  right  : 2016-07-20-SPOT6
#  status : empty
#  ---------,
#  ---------
#  type   : GMC_Pair
#  pzone  : pierre-brune
#  left   : 2001-08-01-AERIAL
#  right  : 2016-07-21-AERIAL
#  status : empty
#  ---------,
#  ---------
#  type   : GMC_Pair
#  pzone  : pierre-brune
#  left   : 2001-08-01-AERIAL
#  right  : 2017-06-17-SPOT6
#  status : empty
#  ---------,
#  ---------
#  type   : GMC_Pair
#  pzone  : pierre-brune
#  left   : 2001-08-01-AERIAL
# ...
