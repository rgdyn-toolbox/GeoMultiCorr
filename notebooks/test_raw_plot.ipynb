# %%
import os

from pathlib import Path

import geoutils as gu
import geomulticorr as gmc
from geomulticorr.utils.gmc_functions import plot_show_raw_results

# %%
disparity_path = Path("/home/cusicand/03_Data/GMC_projects/MultiSensor/raster_data_MultiSensor/MontVallon/image_correlation/MontVallon_2014-09-13-spot6_2018-09-27-spot6/")
left_fn = gu.Raster(disparity_path / "MontVallon_2014-09-13-spot6_2018-09-27-spot6-L.tif")
right_fn = gu.Raster(disparity_path / "MontVallon_2014-09-13-spot6_2018-09-27-spot6-R.tif")
xDisp_fn = gu.Raster(disparity_path / "MontVallon_2014-09-13-spot6_2018-09-27-spot6-F_EW.tif")
yDisp_fn = gu.Raster(disparity_path / "MontVallon_2014-09-13-spot6_2018-09-27-spot6-F_NS.tif")
GoodPixMap_fn = gu.Raster(disparity_path / "MontVallon_2014-09-13-spot6_2018-09-27-spot6-F.tif", bands=[3])
ncc_fn = gu.Raster(disparity_path / "MontVallon_2014-09-13-spot6_2018-09-27-spot6-ncc.tif")

# %%
fig = plot_show_raw_results(
    left=left_fn,
    right=right_fn,
    xDisp=xDisp_fn,
    yDisp=yDisp_fn,
    GoodPixMap=GoodPixMap_fn,
    ncc=ncc_fn,
)
